# %% [markdown]
# <a href="https://colab.research.google.com/github/aslbekrazzoqberdi/My-Projects/blob/main/10_Project_Data_Analy_Company.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### LOAD THE DATASET AND NAME IT AS SURVEY

# %%
survey = pd.read_excel("/content/drive/MyDrive/survey2.xlsx")
survey
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1      2017-05-24       Rural               12th Pass
# 1               2      2017-05-24       Rural                Graduate
# 2               3      2017-05-24       Rural                Graduate
# 3               4      2017-05-24       Urban                Graduate
# 4               5      2017-05-24       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863      2017-06-01       Rural               10th Pass
# 6863         6864      2017-06-01       Rural                Graduate
# 6864         6865      2017-06-01       Urban                Graduate
# 6865         6866      2017-06-01       Rural  Professional Education
# 6866         6867      2017-06-01       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %% [markdown]
# ### HOW MANY SAMPLES COLLECTED ON EACH DAY

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied  25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied  36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied  22   Male
#
#    assembly_no category    weight
# ...

# %%
survey['collection_date'].unique()
# Out:
# array(['2017-05-24T00:00:00.000000000', '2017-05-25T00:00:00.000000000',
#        '2017-05-26T00:00:00.000000000', '2017-05-27T00:00:00.000000000',
#        '2017-05-28T00:00:00.000000000', '2017-05-29T00:00:00.000000000',
#        '2017-05-30T00:00:00.000000000', '2017-05-31T00:00:00.000000000',
#        '2017-06-01T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
survey['collection_date'].nunique()
# Out:
# 9

# %%
survey['collection_date'].value_counts()
# Out:
# 2017-05-24    1479
# 2017-05-25     998
# 2017-05-28     761
# 2017-05-27     665
# 2017-05-29     620
# 2017-06-01     607
# 2017-05-26     598
# 2017-05-30     582
# 2017-05-31     557
# Name: collection_date, dtype: int64

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied  25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied  36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied  22   Male
#
#    assembly_no category    weight
# ...

# %%
survey.shape
# Out:
# (6867, 14)

# %%
survey.age.value_counts()
# Out:
# 25      598
# 24      449
# 30      440
# 28      396
# 22      392
# 26      389
# 27      360
# 20      328
# 23      317
# 21      311
# 32      263
# 35      263
# 29      239
# 40      177
# 34      173
# 19      171
# 31      159
# 33      143
# 38      135
# 36      127
# 18      125
# 42      104
# 37       90
# 45       82
# 43       72
# 39       69
# 50       60
# 41       54
# 44       54
# 48       35
# 47       34
# 46       32
# 49       27
# 52       24
# 51       23
# 55       20
# 60       15
# 53       12
# 61       12
# 54       11
# 57       10
# 56        9
# 58        9
# 64        8
# 67        7
# 62        5
# 59        5
# 65        5
# 68        4
# 63        4
# 66        4
# 70        3
# 71        2
# 74        1
# 24ko      1
# 69        1
# 99        1
# 72        1
# 75        1
# 76        1
# Name: age, dtype: int64

# %%
survey['age'].unique().shape
# Out:
# (60,)

# %%
survey[survey['age'] == '24ko']
# Out:
#      response_id collection_date urban_rural          education  \
# 123          124      2017-05-24       Rural  Post - Graduation
#
#                 income Vote_Now Past_Vote  CM_satisfaction  \
# 123  BPL/Below ₹ 5,000    JD(U)    Others  Fully Satisfied
#
#           MLA_satisfaction   age gender  assembly_no category    weight
# 123  Somewhat Dissatisfied  24ko   Male          180      Gen  2.092567

# %%
survey['age'].replace({'24ko':24}, inplace = True)

# %%
survey['age'].dtype
# Out:
# dtype('int64')

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22   Male
#
#    assembly_no category    weight
# ...

# %% [markdown]
# #### WHAT PROPORTION OF THE TOTAL RESPONDENTS  WERE AGED LESS THAN 45

# %%
x = survey[survey['age'] < 45].shape
x
# Out:
# (6399, 14)

# %%
y = survey.shape

# %%
y
# Out:
# (6867, 14)

# %%
(6399/6867)*100
# Out:
# 93.18479685452162

# %% [markdown]
# ### CREATE NEW COLUMN "AGE_GROUP"

# %%
data = survey.copy()

# %%
data.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22   Male
#
#    assembly_no category    weight
# ...

# %%
survey.age
# Out:
# 0       26
# 1       34
# 2       25
# 3       36
# 4       22
#         ..
# 6862    25
# 6863    30
# 6864    20
# 6865    23
# 6866    33
# Name: age, Length: 6867, dtype: int64

# %%
data
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1      2017-05-24       Rural               12th Pass
# 1               2      2017-05-24       Rural                Graduate
# 2               3      2017-05-24       Rural                Graduate
# 3               4      2017-05-24       Urban                Graduate
# 4               5      2017-05-24       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863      2017-06-01       Rural               10th Pass
# 6863         6864      2017-06-01       Rural                Graduate
# 6864         6865      2017-06-01       Urban                Graduate
# 6865         6866      2017-06-01       Rural  Professional Education
# 6866         6867      2017-06-01       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %% [markdown]
# ### FILTERING WITH 'AND'  OPERATOR

# %%
data1 = data[(data['age_group'] >= 18)  & (data['age_group'] < 25)]
data1
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5      2017-05-24       Rural                Graduate
# 8               9      2017-05-24       Urban               12th Pass
# 14             15      2017-05-24       Rural                Graduate
# 16             17      2017-05-24       Rural       Post - Graduation
# 18             19      2017-05-24       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859      2017-06-01       Rural                Graduate
# 6859         6860      2017-06-01       Urban       Post - Graduation
# 6861         6862      2017-06-01       Rural                Graduate
# 6864         6865      2017-06-01       Urban                Graduate
# 6865         6866      2017-06-01       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data1['age_group'].shape
# Out:
# (2094,)

# %%
data2 = data[(data['age_group'] >= 25)  & (data['age_group'] < 40)]

# %%
data2
# Out:
#       response_id collection_date urban_rural  education               income  \
# 0               1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1               2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2               3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3               4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 5               6      2017-05-24       Urban   Graduate  ₹ 20,000 - ₹ 30,000
# ...           ...             ...         ...        ...                  ...
# 6855         6856      2017-06-01       Rural  12th Pass   ₹ 5,000 - ₹ 10,000
# 6860         6861      2017-06-01       Rural   Graduate    BPL/Below ₹ 5,000
# 6862         6863      2017-06-01       Rural  10th Pass    BPL/Below ₹ 5,000
# 6863         6864      2017-06-01       Rural   Graduate    BPL/Below ₹ 5,000
# 6866         6867      2017-06-01       Rural  10th Pass   ₹ 5,000 - ₹ 10,000
#
# ...

# %%
data2['age_group'].unique()
# Out:
# array([26, 34, 25, 36, 38, 29, 30, 39, 37, 32, 27, 28, 35, 31, 33])

# %% [markdown]
# ### HOW MANY SAMPLES COLLECTED FOR EACH GROUP WHICH ONE IS MOST

# %%
data['age_group'].value_counts()
# Out:
# 25    598
# 24    450
# 30    440
# 28    396
# 22    392
# 26    389
# 27    360
# 20    328
# 23    317
# 21    311
# 32    263
# 35    263
# 29    239
# 40    177
# 34    173
# 19    171
# 31    159
# 33    143
# 38    135
# 36    127
# 18    125
# 42    104
# 37     90
# 45     82
# 43     72
# 39     69
# 50     60
# 44     54
# 41     54
# 48     35
# 47     34
# 46     32
# 49     27
# 52     24
# 51     23
# 55     20
# 60     15
# 61     12
# 53     12
# 54     11
# 57     10
# 56      9
# 58      9
# 64      8
# 67      7
# 59      5
# 65      5
# 62      5
# 66      4
# 68      4
# 63      4
# 70      3
# 71      2
# 74      1
# 69      1
# 99      1
# 72      1
# 75      1
# 76      1
# Name: age_group, dtype: int64

# %% [markdown]
#  ### WHAT PROPORTION OF RESPONDEST HAD OPTED FOR RJD PARTY IN BOTH VOTE_NOW, PAST_VOTE QUESTIONS

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22   Male
#
#    assembly_no category    weight
# ...

# %%
survey[survey['Vote_Now'] == 'RJD'].shape
# Out:
# (1996, 14)

# %%
survey[survey['Past_Vote'] == 'RJD'].shape
# Out:
# (1047, 14)

# %%
survey.shape
# Out:
# (6867, 14)

# %%
(1047/6867) * 100
# Out:
# 15.246832678025338

# %%
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1      2017-05-24       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2      2017-05-24       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3      2017-05-24       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4      2017-05-24       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5      2017-05-24       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22   Male
#
#    assembly_no category    weight
# ...

# %%
# Out:
# 5

# %%
survey['CM_satisfaction'].unique()
# Out:
# array(['Fully Dissatisfied', 'Somewhat Satisfied', 'Fully Satisfied',
#        'Somewhat Dissatisfied', 'Can’t say'], dtype=object)

# %%
CM = survey[survey['CM_satisfaction'] == 'Fully Satisfied']

# %%
CM
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5      2017-05-24       Rural                Graduate
# 8               9      2017-05-24       Urban               12th Pass
# 14             15      2017-05-24       Rural                Graduate
# 17             18      2017-05-24       Urban                Graduate
# 28             29      2017-05-24       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6851         6852      2017-06-01       Urban                Graduate
# 6852         6853      2017-06-01       Rural                Graduate
# 6862         6863      2017-06-01       Rural               10th Pass
# 6865         6866      2017-06-01       Rural  Professional Education
# 6866         6867      2017-06-01       Rural               10th Pass
#
#                    income   Vote_Now     Past_Vote  CM_satisfaction  \
# ...

# %%
a = CM.collection_date.value_counts()

# %%
a
# Out:
# 2017-05-24    146
# 2017-05-25     95
# 2017-05-28     92
# 2017-06-01     75
# 2017-05-29     73
# 2017-05-30     65
# 2017-05-31     62
# 2017-05-26     59
# 2017-05-27     54
# Name: collection_date, dtype: int64

# %%
b = survey.collection_date.value_counts()

# %%
c = (a/b)*100

# %%
print(c)
# Out:
# 2017-05-24     9.871535
# 2017-05-25     9.519038
# 2017-05-26     9.866221
# 2017-05-27     8.120301
# 2017-05-28    12.089356
# 2017-05-29    11.774194
# 2017-05-30    11.168385
# 2017-05-31    11.131059
# 2017-06-01    12.355848
# Freq: D, Name: collection_date, dtype: float64
