# %% [markdown]
# <a href="https://colab.research.google.com/github/aslbekrazzoqberdi/My-Projects/blob/main/Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/car_price.csv')
df
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0                                       Name    Location  Year  \
# 0           0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1           1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2           2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3           3                       Toyota Etios Liva GD   Hyderabad  2012
# 4           4                          Hyundai i20 Magna      Mumbai  2014
# 5           5                     Mahindra XUV500 W8 2WD  Coimbatore  2016
# 6           6        Toyota Fortuner 4x2 AT TRD Sportivo        Pune  2015
# 7           7                       Hyundai EON Era Plus      Jaipur  2013
# 8           8                        Honda City 1.5 S MT      Mumbai  2011
# 9           9                     Mahindra XUV500 W6 2WD  Coimbatore  2015
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# ...

# %%
df.shape
# Out:
# (1234, 13)

# %%
df.isnull()
# Out:
#       Unnamed: 0   Name  Location   Year  Kilometers_Driven  Fuel_Type  \
# 0          False  False     False  False              False      False
# 1          False  False     False  False              False      False
# 2          False  False     False  False              False      False
# 3          False  False     False  False              False      False
# 4          False  False     False  False              False      False
# ...          ...    ...       ...    ...                ...        ...
# 1229       False  False     False  False              False      False
# 1230       False  False     False  False              False      False
# 1231       False  False     False  False              False      False
# 1232       False  False     False  False              False      False
# 1233       False  False     False  False              False      False
#
#       Transmission  Owner_Type  Mileage  Engine  Power  Seats  New_Price
# ...

# %%
df.fillna(10)
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %%
df.isnull()
# Out:
#       Unnamed: 0   Name  Location   Year  Kilometers_Driven  Fuel_Type  \
# 0          False  False     False  False              False      False
# 1          False  False     False  False              False      False
# 2          False  False     False  False              False      False
# 3          False  False     False  False              False      False
# 4          False  False     False  False              False      False
# ...          ...    ...       ...    ...                ...        ...
# 1229       False  False     False  False              False      False
# 1230       False  False     False  False              False      False
# 1231       False  False     False  False              False      False
# 1232       False  False     False  False              False      False
# 1233       False  False     False  False              False      False
#
#       Transmission  Owner_Type  Mileage  Engine  Power  Seats  New_Price
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                 10
# Power                  10
# Seats                  11
# New_Price            1052
# dtype: int64

# %%
df
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %%
df['Year'].isnull().sum()
# Out:
# 0

# %%
df["Seats"].mean()
# Out:
# 5.28454619787408

# %%
df2 = df["Seats"].fillna(df["Seats"].mean())
df2
# Out:
# 0       4.0
# 1       5.0
# 2       7.0
# 3       5.0
# 4       5.0
#        ...
# 1229    5.0
# 1230    5.0
# 1231    5.0
# 1232    5.0
# 1233    5.0
# Name: Seats, Length: 1234, dtype: float64

# %%
df2.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1229    False
# 1230    False
# 1231    False
# 1232    False
# 1233    False
# Name: Seats, Length: 1234, dtype: bool

# %%
df2
# Out:
# 0       4.0
# 1       5.0
# 2       7.0
# 3       5.0
# 4       5.0
#        ...
# 1229    5.0
# 1230    5.0
# 1231    5.0
# 1232    5.0
# 1233    5.0
# Name: Seats, Length: 1234, dtype: float64

# %%
df
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %%
df['Name'].value_counts()
# Out:
# Maruti Alto LXi                                         9
# Honda City 1.5 V MT                                     8
# Volkswagen Polo 1.2 MPI Highline                        8
# Maruti Swift Dzire VDI                                  8
# Audi A6 2011-2015 2.0 TDI Premium Plus                  7
#                                                        ..
# Hyundai Santro GLS I - Euro II                          1
# Honda City i DTec VX Option BL                          1
# Land Rover Discovery 4 SDV6 SE                          1
# Hyundai Verna CRDi 1.6 SX Option                        1
# Mercedes-Benz E-Class 2009-2013 E 220 CDI Avantgarde    1
# Name: Name, Length: 768, dtype: int64

# %%
df["Location"]
# Out:
# 0            Delhi
# 1       Coimbatore
# 2           Mumbai
# 3        Hyderabad
# 4           Mumbai
#            ...
# 1229     Hyderabad
# 1230        Mumbai
# 1231       Kolkata
# 1232          Pune
# 1233         Kochi
# Name: Location, Length: 1234, dtype: object

# %%
df["Location"].value_counts()
# Out:
# Mumbai        159
# Pune          143
# Coimbatore    136
# Hyderabad     134
# Kochi         121
# Kolkata       119
# Delhi         106
# Chennai        97
# Jaipur         86
# Bangalore      82
# Ahmedabad      51
# Name: Location, dtype: int64

# %%
df["Transmission"].value_counts()
# Out:
# Manual       905
# Automatic    329
# Name: Transmission, dtype: int64

# %%
df.head(2)
# Out:
#    Unnamed: 0                           Name    Location  Year  \
# 0           0        Maruti Alto K10 LXI CNG       Delhi  2014
# 1           1  Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage  Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg  998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl  796 CC
#
#       Power  Seats New_Price
# 0  58.2 bhp    4.0       NaN
# 1  47.3 bhp    5.0       NaN

# %%
df[df['Kilometers_Driven'] > 60000]
# Out:
#       Unnamed: 0                                               Name  \
# 3              3                               Toyota Etios Liva GD
# 5              5                             Mahindra XUV500 W8 2WD
# 7              7                               Hyundai EON Era Plus
# 8              8                                Honda City 1.5 S MT
# 10            10                          Audi Q5 2008-2012 2.0 TDI
# ...          ...                                                ...
# 1219        1219                                    Audi A4 2.0 TDI
# 1222        1222                            BMW 5 Series 525d Sedan
# 1224        1224                     Renault Duster 85PS Diesel RxL
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0                                       Name    Location  Year  \
# 0           0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1           1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2           2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3           3                       Toyota Etios Liva GD   Hyderabad  2012
# 4           4                          Hyundai i20 Magna      Mumbai  2014
# 5           5                     Mahindra XUV500 W8 2WD  Coimbatore  2016
# 6           6        Toyota Fortuner 4x2 AT TRD Sportivo        Pune  2015
# 7           7                       Hyundai EON Era Plus      Jaipur  2013
# 8           8                        Honda City 1.5 S MT      Mumbai  2011
# 9           9                     Mahindra XUV500 W6 2WD  Coimbatore  2015
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# ...

# %%
df['Year'] = df['Year'].apply(lambda x : x+10)
df
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...
