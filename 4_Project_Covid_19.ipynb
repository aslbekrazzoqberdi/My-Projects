# %% [markdown]
# <a href="https://colab.research.google.com/github/aslbekrazzoqberdi/My-Projects/blob/main/4_Project_Covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/Covid Data.csv.zip")

# %%
data
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
df = data.head(100)

# %%
df
# Out:
#     USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0       2             1    1             1  03/05/2020       97          1
# 1       2             1    2             1  03/06/2020       97          1
# 2       2             1    2             2  09/06/2020        1          2
# 3       2             1    1             1  12/06/2020       97          2
# 4       2             1    2             1  21/06/2020       97          2
# ..    ...           ...  ...           ...         ...      ...        ...
# 95      2             1    1             1  9999-99-99       97          2
# 96      2             1    1             1  9999-99-99       97          2
# 97      2             1    2             1  9999-99-99       97          2
# 98      2             1    2             1  9999-99-99       97          2
# 99      2             1    1             1  9999-99-99       97          2
#
#     AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  \
# ...

# %%
df.count()
# Out:
# USMER                   100
# MEDICAL_UNIT            100
# SEX                     100
# PATIENT_TYPE            100
# DATE_DIED               100
# INTUBED                 100
# PNEUMONIA               100
# AGE                     100
# PREGNANT                100
# DIABETES                100
# COPD                    100
# ASTHMA                  100
# INMSUPR                 100
# HIPERTENSION            100
# OTHER_DISEASE           100
# CARDIOVASCULAR          100
# OBESITY                 100
# RENAL_CHRONIC           100
# TOBACCO                 100
# CLASIFFICATION_FINAL    100
# ICU                     100
# dtype: int64

# %%
df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
df.groupby('AGE').sum()
# Out:
# <ipython-input-14-f3147dcd504b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('AGE').sum()
#      USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  PREGNANT  \
# AGE
# 16       2             1    2             2        2          2        97
# 19       2             1    2             1       97          2        97
# 20       2             1    1             1       97          2         2
# 23       6             3    3             3      291          6         6
# 24      12             6    8             8      392         12       202
# 25      16             8    9            11      491         15       111
# 26      10             5    5             5      485         10        10
# 27      10             5    9             6      389          9       390
# ...

# %%
df.groupby('AGE')['PREGNANT'].sum().sort_values(ascending = False).head(10)
# Out:
# AGE
# 27    390
# 45    388
# 30    295
# 57    293
# 24    202
# 28    200
# 59    194
# 33    194
# 55    194
# 25    111
# Name: PREGNANT, dtype: int64

# %% [markdown]
# ### REMOVE ALL RECORDS WHERE THE AGE IS LESS THAN 60 :

# %%
df.head(2)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU
# 0               2        2              2        2                     3   97
# 1               2        1              1        2                     5   97
#
# [2 rows x 21 columns]

# %%
df = df[~(df.AGE < 60)]
df
# Out:
#     USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0       2             1    1             1  03/05/2020       97          1
# 1       2             1    2             1  03/06/2020       97          1
# 4       2             1    2             1  21/06/2020       97          2
# 6       2             1    1             1  9999-99-99       97          2
# 7       2             1    1             1  9999-99-99       97          1
# 16      2             1    1             2  9999-99-99        2          1
# 17      2             1    2             1  9999-99-99       97          2
# 19      2             1    1             1  9999-99-99       97          2
# 54      2             1    1             1  9999-99-99       97          2
# 72      2             1    2             1  9999-99-99       97          2
# 84      2             1    2             2  9999-99-99        2          2
# ...

# %%
df.head(10)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
# 5      2             1    1             2  9999-99-99        2          1
# 6      2             1    1             1  9999-99-99       97          2
# 7      2             1    1             1  9999-99-99       97          1
# 8      2             1    1             2  9999-99-99        2          2
# 9      2             1    1             2  9999-99-99        2          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %%
df.head(2)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU
# 0               2        2              2        2                     3   97
# 1               2        1              1        2                     5   97
#
# [2 rows x 21 columns]

# %% [markdown]
# ### IN WHICH AGE MAXIMUM NUMBER OF PREGNANCE

# %%
df.groupby('AGE').PREGNANT.sum().sort_values(ascending = False)
# Out:
# AGE
# 62    99
# 61    97
# 66    97
# 68    97
# 72    97
# 90    97
# 64     6
# 65     2
# 80     2
# Name: PREGNANT, dtype: int64

# %% [markdown]
# #### IN WHICH AGE OBESITY IS MINIMUM

# %%
data.groupby('AGE').OBESITY.sum().sort_values(ascending = True)
# Out:
# AGE
# 121        2
# 111        2
# 113        2
# 114        3
# 115        3
#        ...
# 33     51516
# 29     51771
# 28     52760
# 31     53756
# 30     56167
# Name: OBESITY, Length: 121, dtype: int64
